# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots
import pandas as pd
import seaborn as sns
plt.style.use(['science','grid','bright'])
# %matplotlib inline

# %%
binary_mt_midz = pd.read_table('../m1_60_m2_40_p_6_BD_no_rot_sc_th_basic_net_mid_z/binary_history.data', skiprows = 5, sep ='\s+')
binary_mt_lowz = pd.read_table('../m1_60_m2_40_p_6_BD_no_rot_sc_th_basic_net_low_z/binary_history.data', skiprows = 5, sep ='\s+')
binary_mt_vlowz = pd.read_table('../m1_60_m2_40_p_6_BD_no_rot_sc_th_basic_net_vlow_z/binary_history.data', skiprows = 5, sep ='\s+')
binary_mt_midz_60_5 = pd.read_table('../m1_60_m2_40_p_5_BD_no_rot_sc_th_basic_net_mid_z/binary_history.data', skiprows = 5, sep ='\s+')
binary_mt_midz_50_5 = pd.read_table('../m1_50_m2_40_p_5_BD_no_rot_sc_th_basic_net_mid_z/binary_history.data', skiprows = 5, sep ='\s+')
binary_mt_midz_45_5 = pd.read_table('../m1_45_m2_25_p_5_BD_no_rot_sc_th_basic_net_mid_z/binary_history.data', skiprows = 5, sep ='\s+')
binary_mt_midz_30_5 = pd.read_table('../m1_30_m2_15_p_5_BD_no_rot_sc_th_basic_net_mid_z/binary_history.data', skiprows = 5, sep ='\s+')
binary_mt_midz_25_5 = pd.read_table('../m1_25_m2_15_p_5_BD_no_rot_sc_th_basic_net_mid_z/binary_history.data', skiprows = 5, sep ='\s+')

binary_mt_midz_35_5 = pd.read_table('../m1_35_m2_20_p_5_BD_no_rot_sc_th_basic_net_mid_z/binary_history.data', skiprows = 5, sep ='\s+')
binary_mt_midz_35_5 = binary_mt_midz_35_5.drop(binary_mt_midz_35_5.index[14000:16120])


binary_mt_midz_40_5 = pd.read_table('../m1_40_m2_25_p_5_BD_no_rot_sc_th_basic_net_mid_z/binary_history.data', skiprows = 5, sep ='\s+')
binary_mt_midz_40_5 = binary_mt_midz_40_5.drop(binary_mt_midz_40_5.index[14000:16091])
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:6: SyntaxWarning: invalid escape sequence '\s'
# <>:7: SyntaxWarning: invalid escape sequence '\s'
# <>:8: SyntaxWarning: invalid escape sequence '\s'
# <>:10: SyntaxWarning: invalid escape sequence '\s'
# <>:14: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:6: SyntaxWarning: invalid escape sequence '\s'
# <>:7: SyntaxWarning: invalid escape sequence '\s'
# <>:8: SyntaxWarning: invalid escape sequence '\s'
# <>:10: SyntaxWarning: invalid escape sequence '\s'
# ...

# %%
binary_mt_midz_40_5_z_0100 = pd.read_table('../m1_40_m2_25_p_5_BD_no_rot_sc_th_basic_net_z_0100/binary_history.data', skiprows = 5, sep ='\s+')

binary_mt_midz_40_5_z_0146 = pd.read_table('../m1_40_m2_25_p_5_BD_no_rot_sc_th_basic_net_mid_z/binary_history.data', skiprows = 5, sep ='\s+')
binary_mt_midz_40_5_z_0146 = binary_mt_midz_40_5_z_0146.drop(binary_mt_midz_40_5_z_0146.index[14000:16091])
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_17253/2113812364.py:1: SyntaxWarning: invalid escape sequence '\s'
#   binary_mt_midz_40_5_z_0100 = pd.read_table('../m1_40_m2_25_p_5_BD_no_rot_sc_th_basic_net_z_0100/binary_history.data', skiprows = 5, sep ='\s+')
# /tmp/ipykernel_17253/2113812364.py:3: SyntaxWarning: invalid escape sequence '\s'
#   binary_mt_midz_40_5_z_0146 = pd.read_table('../m1_40_m2_25_p_5_BD_no_rot_sc_th_basic_net_mid_z/binary_history.data', skiprows = 5, sep ='\s+')

# %%
plt.plot(binary_mt_midz_40_5_z_0100['model_number'], binary_mt_midz_40_5_z_0100['star_1_radius'], label = 'Donor')
plt.plot(binary_mt_midz_40_5_z_0100['model_number'], binary_mt_midz_40_5_z_0100['rl_1'], label = 'Roche Lobe')
plt.plot(binary_mt_midz_40_5_z_0100['model_number'], binary_mt_midz_40_5_z_0100['binary_separation'], label = 'Separation')
plt.xlabel('Model')
plt.ylabel('Radius')
plt.suptitle('Z = 0.0100 (40+25,5)')
plt.legend()
plt.show()

plt.plot(binary_mt_midz_40_5_z_0146['model_number'], binary_mt_midz_40_5_z_0146['star_1_radius'], label = 'Donor')
plt.plot(binary_mt_midz_40_5_z_0146['model_number'], binary_mt_midz_40_5_z_0146['rl_1'], label = 'Roche Lobe')
plt.plot(binary_mt_midz_40_5_z_0146['model_number'], binary_mt_midz_40_5_z_0146['binary_separation'], label = 'Separation')
plt.xlabel('Model')
plt.ylabel('Radius')
plt.suptitle('Z = 0.0146 (40+25,5)')
plt.legend()
plt.show()

# %%
plt.plot(binary_mt_midz['age']/1e6, binary_mt_midz['star_1_mass'], label = 'Donor')
plt.plot(binary_mt_midz['age']/1e6, binary_mt_midz['star_2_mass'], label = 'Accretor')
plt.xlabel('Age (Myr)')
plt.ylabel('Mass')
plt.suptitle('Z = 0.0146 (60+40,6)')
#plt.xlim(2,4.5)
plt.legend()
plt.show()

plt.plot(binary_mt_midz_25_5['age']/1e6, binary_mt_midz_25_5['star_1_mass'], label = 'Donor')
plt.plot(binary_mt_midz_25_5['age']/1e6, binary_mt_midz_25_5['star_2_mass'], label = 'Accretor')
plt.xlabel('Age (Myr)')
plt.ylabel('Mass')
plt.suptitle('Z = 0.0146 (25+15,5)')
#plt.xlim(2,4.5)
plt.legend()
plt.show()

plt.plot(binary_mt_midz_30_5['age']/1e6, binary_mt_midz_30_5['star_1_mass'], label = 'Donor')
plt.plot(binary_mt_midz_30_5['age']/1e6, binary_mt_midz_30_5['star_2_mass'], label = 'Accretor')
plt.xlabel('Age (Myr)')
plt.ylabel('Mass')
plt.suptitle('Z = 0.0146 (30+15,5)')
#plt.xlim(2,4.5)
plt.legend()
plt.show()

plt.plot(binary_mt_midz_45_5['age']/1e6, binary_mt_midz_45_5['star_1_mass'], label = 'Donor')
plt.plot(binary_mt_midz_45_5['age']/1e6, binary_mt_midz_45_5['star_2_mass'], label = 'Accretor')
plt.xlabel('Age (Myr)')
plt.ylabel('Mass')
plt.suptitle('Z = 0.0146 (45+25,5)')
#plt.xlim(2,4.5)
plt.legend()
plt.show()

plt.plot(binary_mt_midz_50_5['age']/1e6, binary_mt_midz_50_5['star_1_mass'], label = 'Donor')
plt.plot(binary_mt_midz_50_5['age']/1e6, binary_mt_midz_50_5['star_2_mass'], label = 'Accretor')
plt.xlabel('Age (Myr)')
plt.ylabel('Mass')
plt.suptitle('Z = 0.0146 (50+40,5)')
#plt.xlim(2,4.5)
plt.legend()
plt.show()

plt.plot(binary_mt_midz_60_5['age']/1e6, binary_mt_midz_60_5['star_1_mass'], label = 'Donor')
plt.plot(binary_mt_midz_60_5['age']/1e6, binary_mt_midz_60_5['star_2_mass'], label = 'Accretor')
plt.xlabel('Age (Myr)')
plt.ylabel('Mass')
plt.suptitle('Z = 0.0146 (60+40,5)')
#plt.xlim(2,4.5)
plt.legend()
plt.show()

plt.plot(binary_mt_lowz['age']/1e6, binary_mt_lowz['star_1_mass'], label = 'Donor')
plt.plot(binary_mt_lowz['age']/1e6, binary_mt_lowz['star_2_mass'], label = 'Accretor')
plt.xlabel('Age (Myr)')
plt.ylabel('Mass')
plt.suptitle('Z = 0.002 (60+40,6)')
#plt.xlim(2,4.5)
plt.legend()
plt.show()

plt.plot(binary_mt_vlowz['age']/1e6, binary_mt_vlowz['star_1_mass'], label = 'Donor')
plt.plot(binary_mt_vlowz['age']/1e6, binary_mt_vlowz['star_2_mass'], label = 'Accretor')
plt.xlabel('Age (Myr)')
plt.ylabel('Mass')
plt.suptitle('Z = 0.0002 (60+40,6)')
#plt.xlim(2,4.5)
plt.legend()
plt.show()

# %%
plt.plot(binary_mt_midz['age']/1e6, binary_mt_midz['star_1_radius'], label = 'Donor Radius')
plt.plot(binary_mt_midz['age']/1e6, binary_mt_midz['rl_1'], label = 'Roche Lobe')
plt.xlabel('Age (Myr)')
plt.ylabel('Radius')
plt.suptitle('Z = 0.0146')
plt.xlim(2,4.2)
plt.legend()
plt.show()

plt.plot(binary_mt_midz_50_5['age']/1e6, binary_mt_midz_50_5['star_1_radius'], label = 'Donor')
plt.plot(binary_mt_midz_50_5['age']/1e6, binary_mt_midz_50_5['rl_1'], label = 'Accretor')
plt.xlabel('Age (Myr)')
plt.ylabel('Radius')
plt.suptitle('Z = 0.0146 (50,5)')
plt.xlim(4.15,4.25)
plt.legend()
plt.show()

plt.plot(binary_mt_midz_25_5['model_number'], binary_mt_midz_25_5['star_1_radius'], label = 'Donor')
plt.plot(binary_mt_midz_25_5['model_number'], binary_mt_midz_25_5['rl_1'], label = 'Roche Lobe')
plt.plot(binary_mt_midz_25_5['model_number'], binary_mt_midz_25_5['binary_separation'], label = 'Separation')
plt.xlabel('Model')
plt.ylabel('Radius')
plt.suptitle('Z = 0.0146 (25+15,5)')
plt.legend()
plt.show()

plt.plot(binary_mt_midz_30_5['model_number'], binary_mt_midz_30_5['star_1_radius'], label = 'Donor')
plt.plot(binary_mt_midz_30_5['model_number'], binary_mt_midz_30_5['rl_1'], label = 'Roche Lobe')
plt.plot(binary_mt_midz_30_5['model_number'], binary_mt_midz_30_5['binary_separation'], label = 'Separation')
plt.xlabel('Model')
plt.ylabel('Radius')
plt.xlim
plt.suptitle('Z = 0.0146 (30+15,5)')
plt.legend()
plt.show()

plt.plot(binary_mt_midz_45_5['model_number'], binary_mt_midz_45_5['star_1_radius'], label = 'Donor')
plt.plot(binary_mt_midz_45_5['model_number'], binary_mt_midz_45_5['rl_1'], label = 'Roche Lobe')
plt.plot(binary_mt_midz_45_5['model_number'], binary_mt_midz_45_5['binary_separation'], label = 'Separation')
plt.xlabel('Model')
plt.ylabel('Radius')
plt.suptitle('Z = 0.0146 (45+25,5)')
plt.legend()
plt.show()

plt.plot(binary_mt_midz_50_5['model_number'], binary_mt_midz_50_5['star_1_radius'], label = 'Donor')
plt.plot(binary_mt_midz_50_5['model_number'], binary_mt_midz_50_5['rl_1'], label = 'Roche Lobe')
plt.xlabel('Model')
plt.ylabel('Radius')
plt.suptitle('Z = 0.0146 (50,5)')
#plt.xlim(4.15,4.25)
plt.legend()
plt.show()

plt.plot(binary_mt_midz_60_5['age']/1e6, binary_mt_midz_60_5['star_1_radius'], label = 'Donor')
plt.plot(binary_mt_midz_60_5['age']/1e6, binary_mt_midz_60_5['rl_1'], label = 'Accretor')
plt.xlabel('Age (Myr)')
plt.ylabel('Radius')
plt.suptitle('Z = 0.0146 (60,5)')
plt.xlim(2,4.2)
plt.legend()
plt.show()

plt.plot(binary_mt_lowz['age']/1e6, binary_mt_lowz['star_1_radius'], label = 'Donor Radius')
plt.plot(binary_mt_lowz['age']/1e6, binary_mt_lowz['rl_1'], label = 'Roche Lobe')
plt.xlabel('Age (Myr)')
plt.ylabel('Radius')
plt.suptitle('Z = 0.002')
plt.xlim(2,4.2)
plt.legend()
plt.show()

plt.plot(binary_mt_vlowz['age']/1e6, binary_mt_vlowz['star_1_radius'], label = 'Donor Radius')
plt.plot(binary_mt_vlowz['age']/1e6, binary_mt_vlowz['rl_1'], label = 'Roche Lobe')
plt.xlabel('Age (Myr)')
plt.ylabel('Radius')
plt.xlim(2,4.2)
plt.suptitle('Z = 0.0002')
plt.legend()
plt.show()

# %%
plt.plot(binary_mt_midz_35_5['model_number'], binary_mt_midz_35_5['star_1_radius'], label = 'Donor')
plt.plot(binary_mt_midz_35_5['model_number'], binary_mt_midz_35_5['rl_1'], label = 'Roche Lobe')
plt.plot(binary_mt_midz_35_5['model_number'], binary_mt_midz_35_5['binary_separation'], label = 'Separation')
plt.xlabel('Model')
plt.ylabel('Radius')
plt.ylim(0,30)
plt.suptitle('Z = 0.0146 (35+20,5)')
plt.legend()
plt.show()

plt.plot(binary_mt_midz_40_5['model_number'], binary_mt_midz_40_5['star_1_radius'], label = 'Donor')
plt.plot(binary_mt_midz_40_5['model_number'], binary_mt_midz_40_5['rl_1'], label = 'Roche Lobe')
plt.plot(binary_mt_midz_40_5['model_number'], binary_mt_midz_40_5['binary_separation'], label = 'Separation')
plt.xlabel('Model')
plt.ylabel('Radius')
plt.ylim(0,30)
plt.suptitle('Z = 0.0146 (40+25,5)')
plt.legend()
plt.show()

# %%
binary_mt_midz_40_5[14000:16091]['model_number']
# Out:
# 14000    14001
# 14001    14002
# 14002    14003
# 14003    14004
# 14004    14005
#          ...
# 16086    16087
# 16087    16088
# 16088    16089
# 16089    16090
# 16090    16090
# Name: model_number, Length: 2091, dtype: int64
