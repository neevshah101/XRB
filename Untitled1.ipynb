# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import astropy.constants as const
import astropy.units as u
import scienceplots
plt.style.use('science')

# %%
i = 15
logs_dir_ss_donor = f'single_star/LOGS1/profile{i}.data'
ss = pd.read_table(logs_dir_ss_donor, sep = '\s+', skiprows = 5)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_22777/2782324505.py:3: SyntaxWarning: invalid escape sequence '\s'
#   ss = pd.read_table(logs_dir_ss_donor, sep = '\s+', skiprows = 5)

# %%
for i in range(1,18):
    
    logs_dir_ss_donor = f'single_star/LOGS1/profile{i}.data'
    ss = pd.read_table(logs_dir_ss_donor, sep = '\s+', skiprows = 5)
    
    plt.plot(ss['mass'], ss['he4'])
    plt.suptitle(f'profile = {i}')
    plt.ylim(0,1)
    plt.show()
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_22777/1929823768.py:4: SyntaxWarning: invalid escape sequence '\s'
#   ss = pd.read_table(logs_dir_ss_donor, sep = '\s+', skiprows = 5)
