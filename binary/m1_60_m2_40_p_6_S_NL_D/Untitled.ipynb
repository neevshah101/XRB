# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots
import pandas as pd
plt.style.use(['science','grid','bright'])
# %matplotlib inline

# %%
logs_dir = '/home/u16/neevshah/Projects/XRB/binary/m1_60_m2_40_p_6_B_NL_D/LOGS1'
columns = ['star_age','star_mass','log_R','log_Teff','log_L']
donor_B = pd.read_table(logs_dir+'/history.data', sep = '\s+', skiprows = 5)

logs_dir = '/home/u16/neevshah/Projects/XRB/binary/m1_60_m2_40_p_6_B_NL_D'
columns = ['star_age','star_mass','log_R','log_Teff','log_L']
binary_B = pd.read_table(logs_dir+'/binary_history.data', sep = '\s+', skiprows = 5)

logs_dir = '/home/u16/neevshah/Projects/XRB/binary/m1_60_m2_40_p_6_S_NL_D/LOGS1'
columns = ['star_age','star_mass','log_R','log_Teff','log_L']
donor_S = pd.read_table(logs_dir+'/history.data', sep = '\s+', skiprows = 5)

logs_dir = '/home/u16/neevshah/Projects/XRB/binary/m1_60_m2_40_p_6_S_NL_D'
columns = ['star_age','star_mass','log_R','log_Teff','log_L']
binary_S = pd.read_table(logs_dir+'/binary_history.data', sep = '\s+', skiprows = 5)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:7: SyntaxWarning: invalid escape sequence '\s'
# <>:11: SyntaxWarning: invalid escape sequence '\s'
# <>:15: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:7: SyntaxWarning: invalid escape sequence '\s'
# <>:11: SyntaxWarning: invalid escape sequence '\s'
# <>:15: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_8180/1262639061.py:3: SyntaxWarning: invalid escape sequence '\s'
#   donor_B = pd.read_table(logs_dir+'/history.data', sep = '\s+', skiprows = 5)
# /tmp/ipykernel_8180/1262639061.py:7: SyntaxWarning: invalid escape sequence '\s'
#   binary_B = pd.read_table(logs_dir+'/binary_history.data', sep = '\s+', skiprows = 5)
# /tmp/ipykernel_8180/1262639061.py:11: SyntaxWarning: invalid escape sequence '\s'
#   donor_S = pd.read_table(logs_dir+'/history.data', sep = '\s+', skiprows = 5)
# ...

# %%
plt.plot(binary_B[:-1]['age'], 10**donor_B['log_Teff'])
plt.plot(binary_S['age'], 10**donor_S['log_Teff'])
#plt.plot(binary['age'], binary['rl_1'])
#plt.ylim(20000,50000)

# %%
plt.plot(binary_B['age'], binary_B['star_1_radius'], color = 'C0')
plt.plot(binary_B['age'], binary_B['rl_1'], ls = '--', color = 'C0')
plt.plot(binary_S['age'], binary_S['star_1_radius'], color = 'C1')
plt.plot(binary_S['age'], binary_S['rl_1'], ls = '--', color = 'C1')
